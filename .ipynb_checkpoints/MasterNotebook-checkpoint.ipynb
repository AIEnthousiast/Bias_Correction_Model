# %%
import numpy as np
import pandas as pd

# %% [markdown]
# We start by conducting a basic EDA on the data of one station , in this case station_0.

# %%
station_0_data = pd.read_csv("Data_csv/Station_00.csv")

# %%
station_0_data.head()
# Out:
#    Year  Month  Day  T obs  T mod  P obs  P mod  H obs  H mod  W obs  W mod  \
# 0  2001      1    1    NaN   0.97    NaN   0.00    NaN  32.22   4.95   2.67
# 1  2001      1    2    NaN   4.20    NaN   0.41    NaN  79.75   3.01   2.41
# 2  2001      1    3    NaN   1.47    NaN   2.39    NaN  83.82   3.15   3.00
# 3  2001      1    4    NaN   3.07    NaN   4.32    NaN  67.58   5.13   3.73
# 4  2001      1    5    NaN   4.65    NaN   0.74    NaN  59.15   6.84   5.14
#
#    SW obs  SW mod
# 0     NaN   77.18
# 1     NaN   69.72
# 2     NaN   55.23
# 3     NaN   73.89
# 4     NaN   74.07

# %%
station_0_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    3287 non-null   int64
#  1   Month   3287 non-null   int64
#  2   Day     3287 non-null   int64
#  3   T obs   1331 non-null   float64
#  4   T mod   3287 non-null   float64
#  5   P obs   0 non-null      float64
#  6   P mod   3287 non-null   float64
#  7   H obs   1331 non-null   float64
#  8   H mod   3287 non-null   float64
#  9   W obs   3024 non-null   float64
#  10  W mod   3287 non-null   float64
#  11  SW obs  0 non-null      float64
#  12  SW mod  3287 non-null   float64
# dtypes: float64(10), int64(3)
# memory usage: 334.0 KB

# %% [markdown]
# # Data visualization

# %%
import datetime

# %%
pd.options.mode.chained_assignment = None
station_0_data_augmented = station_0_data[::]
station_0_data_augmented["full_date"] = pd.to_datetime(station_0_data_augmented[["Year","Month","Day"]])
"""
station_0_data_indexed = station_0_data_augmented.set_index("full_date")
station_0_data_indexed.head()
"""
# Out:
# '\nstation_0_data_indexed = station_0_data_augmented.set_index("full_date")\nstation_0_data_indexed.head()\n'

# %% [markdown]
# First question : how does the modeled values fair against the observed data ?
#
# We first explore this question at a glance, looking at lineplots for each modeled value and pair of observed and modeled data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
targets = ["P","T","H"]
obs_targets = [t + " obs" for t in targets]
mod_targets = [t +  " mod" for t in targets]

plt.figure(figsize=(15,9))
for idx in range(len(targets)):
    ax = plt.subplot(len(targets), 1, idx + 1)
    sns.lineplot(x=station_0_data_augmented["full_date"], 
             y=station_0_data_augmented[obs_targets[idx]],ax = ax,label=f"{obs_targets[idx]}")
    plt.xlim(station_0_data_augmented["full_date"].min(),station_0_data_augmented["full_date"].max())
    sns.lineplot(x=station_0_data_augmented["full_date"], 
             y=station_0_data_augmented[mod_targets[idx]],ax = ax,label=f"{mod_targets[idx]}")

    plt.tight_layout()
plt.show()

# %% [markdown]
# As seen above, some data is missing. For instance, no data can be found for the values of the precipitations for station 0. As for the temperature, the data there is no value before the last third of 2005.
#
# Notwithstanding, on the data we have i.e 2006 onwards (except a period of time in mid 2009), we observe that the modeled temperature is overall somewhat close to the observed temperature. However, there seems to be visually speaking a slight shift / bias upwards from the model with respect to the observed data.
#
# Let us investigate this further.

# %%
plt.figure(figsize=(20,15))
for idx in range(len(targets)):
    ax = plt.subplot(len(targets), 1, idx+1)

    sns.scatterplot(x=station_0_data_augmented[obs_targets[idx]], y = station_0_data_augmented[mod_targets[idx]])

    ax.set_xlabel(f"{obs_targets[idx]}")
    ax.set_ylabel(f"{mod_targets[idx]}")
    
    plt.tight_layout()
plt.savefig("station_0.png")
plt.show()*

# %%
from sklearn.metrics import r2_score


for idx in range(len(targets)):
    try:
        obs  =  station_0_data_index.loc[:,obs_targets[idx]]
        mod  = station_0_data_index.loc[:,mod_targets[idx]]
        mod, obs = obs.align(mod, join="inner") #aligns values by date
        mask =pd.isna(station_0_data_index[obs_targets[idx]]) & (pd.isna(station_0_data_index[mod_targets[idx]]) == False) 
        mask =  ~mask #mask for detecting all valid pair of data
        print(f"R2 score ({targets[idx]}): {r2_score(mod[mask],
                                                    obs[mask])}")
    except Exception as e :
        pass
# Out:
# R2 score (T): 0.8646758671103391
# R2 score (H): 0.6833428714746874

# %% [markdown]
# As shown in the plot, there seems to be a strong linear correlation between the model output and the observed value for the temperature, as it should.
# In addition, the r2 score shows that the model explains 86.4% percent of the variance of the observed temperature.
#
# This conforts us in our intuition that the model has grasped the gist of the observed data.

# %%
for idx in range(len(targets)):
    station_0_data_augmented[f"Delta_{targets[idx]}"] = station_0_data_augmented[obs_targets[idx]] - station_0_data_augmented[mod_targets[idx]]

# %%
station_0_data_augmented.head(-5)
# Out:
#       Year  Month  Day  T obs  T mod  P obs  P mod  H obs  H mod  W obs  \
# 0     2001      1    1    NaN   0.97    NaN   0.00    NaN  32.22   4.95
# 1     2001      1    2    NaN   4.20    NaN   0.41    NaN  79.75   3.01
# 2     2001      1    3    NaN   1.47    NaN   2.39    NaN  83.82   3.15
# 3     2001      1    4    NaN   3.07    NaN   4.32    NaN  67.58   5.13
# 4     2001      1    5    NaN   4.65    NaN   0.74    NaN  59.15   6.84
# ...    ...    ...  ...    ...    ...    ...    ...    ...    ...    ...
# 3277  2009     12   22   3.74   5.35    NaN   1.37  43.20  65.47  10.42
# 3278  2009     12   23  -0.34   0.83    NaN   0.69  85.78  93.70   4.30
# 3279  2009     12   24   6.28   5.70    NaN   0.51  51.66  86.03   7.62
# 3280  2009     12   25   0.93   2.07    NaN  13.13  81.50  85.37   4.67
# 3281  2009     12   26  -4.87  -1.42    NaN   0.00  47.02  44.95   4.30
#
#       W mod  SW obs  SW mod  full_date  Delta_P  Delta_T  Delta_H
# 0      2.67     NaN   77.18 2001-01-01      NaN      NaN      NaN
# 1      2.41     NaN   69.72 2001-01-02      NaN      NaN      NaN
# 2      3.00     NaN   55.23 2001-01-03      NaN      NaN      NaN
# 3      3.73     NaN   73.89 2001-01-04      NaN      NaN      NaN
# 4      5.14     NaN   74.07 2001-01-05      NaN      NaN      NaN
# ...     ...     ...     ...        ...      ...      ...      ...
# 3277   5.93     NaN   71.02 2009-12-22      NaN    -1.61   -22.27
# 3278   2.25     NaN   63.33 2009-12-23      NaN    -1.17    -7.92
# 3279   3.30     NaN   62.69 2009-12-24      NaN     0.58   -34.37
# 3280   3.80     NaN   25.19 2009-12-25      NaN    -1.14    -3.87
# 3281   3.23     NaN   76.48 2009-12-26      NaN    -3.45     2.07
#
# [3282 rows x 17 columns]

# %%
station_0_data_augmented.index = station_0_data_augmented["full_date"]

# %%
plt.figure(figsize=(20,15))
for idx in range(len(targets)):
    ax = plt.subplot(len(targets), 1, idx+1)

    sns.kdeplot(station_0_data_augmented[obs_targets[idx]],label=f"{obs_targets[idx]}",ax=ax)
    sns.kdeplot(station_0_data_augmented[mod_targets[idx]],label=f"{mod_targets[idx]}",ax=ax)
    ax.set_xlabel(f"Distribution of {targets[idx]}")
    plt.legend()
    plt.tight_layout()
# Out:
# C:\Users\HP Z\AppData\Local\Temp\ipykernel_8256\3147824194.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(station_0_data_augmented[obs_targets[idx]],label=f"{obs_targets[idx]}",ax=ax)

# %%
plt.figure(figsize=(20,15))
for idx in range(len(targets)):
    ax = plt.subplot(len(targets), 1, idx+1)

    sns.histplot(station_0_data_augmented[f"Delta_{targets[idx]}"],label=f"{obs_targets[idx]}",ax=ax)
    ax.set_xlabel(f"Distribution of residuals {targets[idx]}")
    
    plt.tight_layout()
